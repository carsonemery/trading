# %% [markdown]
# Replicating Main Results From **Intraday Residual Reversal in the U.S. Stock Market** Brogaard, Han, Kim

# %% [markdown]
# Notes to self for my implementation
#
# Page 10 - Data.
#
# 1) Select the last bid and ask quote price every 30 minutes between the hours of 10:00AM and 4:00PM EST
#
# * using the TAQ database from July 1996 to Dec 2022 and S&P based equities
#
# 2) This results in a total of 13 quote price obersvations per day for each stock
# 3) Forward fill cases where there was not a quote on a given 30 minute interval
# 4) Calculate the midpoint of the bid and ask quote to get a return measure
# 5) use CFACPR to adjust share price
# 6) winsorize 30 min returns at 0.5% level to adjust for remaining large outliers
#
#
# Page 11/12 - RET, RESIDUAL and RISK intro.
#
# 1) Return or RET is composed of RISK and RESIDUAL, where RISK is return attributable to factors and RESIDUAL is noise left from subtracting RISK from RET
# 2) Page 55 begins to list the 15 anomalies used

# %%
# Getting the universe we want to query for intraday data
import pandas as pd
from pathlib import Path

from bearplanes.utils.paths import *
from bearplanes.utils.adjustment import *
from bearplanes.utils.describe_dataframes import *

# Load in raw crsp data to refilter 
data_path = get_raw_data_dir(source='wrds', dataset='crsp')
df = pd.read_parquet(get_file_path(data_path, 'crsp_dsf_cleaned.parquet'))

# Going to apply row level filters to filter the data set
# since wrds no longer provides historical S&P constituents I think this makes sense, I could be a little more accurate and use S&P documentation on eligibility.
# Filter for quality
df_filtered = df[
    (df['adj_volume'] > 10_000_000) &
    (df['adj_close'] > 5) &
    (df['sharetype'] == 'NS') &
    (df['primaryexch'].isin(['A', 'Q', 'N'])) &
    (df['tradingstatusflg'] == 'A')
]

# Convert to datetime BEFORE creating universe_df
df_filtered['dlycaldt'] = pd.to_datetime(df_filtered['dlycaldt'])

# Filter for date range
df_filtered = df_filtered[df_filtered['dlycaldt'] >= pd.to_datetime('2015-01-01')]

# NOW create universe_df
universe_df = df_filtered[['ticker', 'dlycaldt', 'permno']]

universe_df.to_parquet(f'{data_path}/universe.parquet')

# %%
# Compustat fundamentals
from pathlib import Path
import pandas as pd

from bearplanes.utils.paths import *
from bearplanes.utils.adjustment import *
from bearplanes.utils.describe_dataframes import *

# Load in raw compustat data to concatenate into one 
compustat_file = get_raw_data_dir(source='wrds', dataset='compustat_fundamentals_q')
data_path = compustat_file / 'fundq_combined.parquet'

comp_df = pd.read_parquet(data_path)
# print(comp_df)

comp_df.cust.describe()
contains_iid = any(['iid' == col_name for col_name in comp_df.columns])
contains_permno = any(['permno' == col_name for col_name in comp_df.columns])

print(f"contains permno {contains_permno}")
print(f"contains iid {contains_iid}")
# Out:
# ============================================================
# BASIC INFORMATION
# ============================================================
# Dimensions: 476,593 rows × 395 columns
# ------------------------------------------------------------
# Column Data Types:
# gvkey       string[python]
# iid         string[python]
# datadate    string[python]
# fyearq               Int64
# fqtr                 Int64
#                  ...
# dvpsxq             Float64
# mkvaltq            Float64
# prccq              Float64
# prchq              Float64
# prclq              Float64
# Length: 395, dtype: object
# ============================================================
#
# ============================================================
# MEMORY USAGE
# ============================================================
# Total memory: 2208.30 MB
# ============================================================
#
# ============================================================
# MISSING VALUES ANALYSIS
# ============================================================
# column_name  missing_count  percent_missing
#       gvkey              0         0.000000
#         iid             30         0.006295
#    datadate              0         0.000000
#      fyearq              0         0.000000
#        fqtr            125         0.026228
#        conm              0         0.000000
#         tic            131         0.027487
#       cusip            119         0.024969
#         cik         150799        31.641044
#      indfmt              0         0.000000
#      consol              0         0.000000
#     datafmt              0         0.000000
#      popsrc              0         0.000000
#       exchg            127         0.026647
#         fyr              0         0.000000
#    acctchgq         464400        97.441633
#    acctstdq         141128        29.611849
#       ajexq              5         0.001049
#        ajpq              5         0.001049
#   apdedateq         164784        34.575413
#       bsprq         419707        88.064029
#         rdq         169012        35.462544
#      fdateq         140657        29.513023
#      pdateq         279300        58.603462
#      finalq         140651        29.511764
#        updq              0         0.000000
#     compstq         454394        95.342147
#        srcq         138635        29.088761
#     curncdq         163112        34.224590
#     currtrq         163112        34.224590
#    datacqtr            504         0.105751
#    datafqtr            130         0.027277
#      staltq         476092        99.894879
#      acchgq         177477        37.238692
#    acomincq         173687        36.443464
#        acoq         190010        39.868399
#        actq         219339        46.022287
#       altoq         199215        41.799817
#        ancq         228595        47.964406
#        anoq         302656        63.504080
#  aociderglq         187921        39.430080
#  aociotherq         183055        38.409083
#    aocipenq         186583        39.149337
#  aocisecglq         183392        38.479793
#       aol2q         302824        63.539330
#         aoq         167123        35.066189
#         apq         169423        35.548781
#        aqaq         440155        92.354483
#      aqpl1q         302736        63.520866
#        aqpq         409975        86.022036
#         atq         166125        34.856786
#       aul3q         302721        63.517718
#      capr1q         456891        95.866074
#      capr2q         457024        95.893981
#      capr3q         456712        95.828516
#     capsftq         450075        94.435923
#       capsq         184538        38.720250
#        ceqq         167161        35.074162
#        cheq         167055        35.051921
#         chq         189803        39.824966
#    cibegniq         166923        35.024224
#     cicurrq         169285        35.519825
#    ciderglq         168923        35.443869
#      cimiiq         166886        35.016461
#    ciotherq         167200        35.082345
#      cipenq         168193        35.290699
#         ciq         166875        35.014153
#    cisecglq         169027        35.465691
#    citotalq         166745        34.986876
#       cogsq         158488        33.254370
#      csh12q         152297        31.955358
#     cshfd12         152319        31.959974
#      cshfdq         149629        31.395551
#       cshiq         181442        38.070639
#      cshopq         346435        72.689905
#       cshoq          30348         6.367697
#      cshprq         149612        31.391984
#      cstkeq         156663        32.871444
#       cstkq         179505        37.664212
#       dcomq         200380        42.044260
#        dd1q         224951        47.199812
#      deracq         421494        88.438983
#     deraltq         416806        87.455334
#   derhedglq         404712        84.917739
#      derlcq         408008        85.609314
#     derlltq         405098        84.998731
#      diladq         163619        34.330970
#      dilavq         163683        34.344399
#        dlcq         184236        38.656883
#       dlttq         168817        35.421628
#         doq         156637        32.865988
#      dpactq         283469        59.478213
#         dpq         185289        38.877827
#        drcq         227301        47.692895
#       drltq         211206        44.315800
#       dteaq         451861        94.810667
#       dtepq         436125        91.508898
#        dvpq         156790        32.898091
#      epsf12         179840        37.734503
#     epsfi12         179824        37.731146
#      epsfiq         164339        34.482042
#      epsfxq         164346        34.483511
#     epspi12         179812        37.728628
#      epspiq         164336        34.481413
#      epspxq         164343        34.482882
#      epsx12         179392        37.640502
#        fcaq         354631        74.409612
#     findlcq         476003        99.876205
#     findltq         475752        99.823539
#    finreccq         475438        99.757655
#   finrecltq         475647        99.801508
#     finrevq         475172        99.701842
#    finxintq         475762        99.825637
#     gdwlamq         476593       100.000000
#    gdwlia12         465092        97.586830
#     gdwliaq         470008        98.618318
#    gdwlid12         465350        97.640964
#     gdwlipq         465199        97.609281
#       gdwlq         178473        37.447675
#        glaq         463317        97.214395
#     glcea12         468729        98.349955
#      glceaq         473676        99.387947
#      glcedq         474200        99.497894
#      glcepq         472144        99.066499
#       glivq         421467        88.433317
#        glpq         455174        95.505809
#     ibadj12         364124        76.401458
#      ibadjq         156635        32.865569
#      ibcomq         156678        32.874591
#      ibmiiq         166121        34.855946
#         ibq         156656        32.869975
#      icaptq         167311        35.105635
#     intaccq         470228        98.664479
#     intanoq         190318        39.933025
#      intanq         169282        35.519196
#      invfgq         265382        55.683151
#       invoq         264386        55.474168
#      invrmq         266705        55.960746
#       invtq         173083        36.316731
#     invwipq         267100        56.043626
#      ivaeqq         469868        98.588943
#       ivaoq         468204        98.239798
#       ivltq         221522        46.480330
#       ivstq         198338        41.615802
#        lcoq         190044        39.875533
#        lctq         219144        45.981372
#        lltq         228399        47.923280
#        lnoq         302614        63.495267
#       lol2q         302687        63.510585
#         loq         166742        34.986246
#      loxdrq         199307        41.819120
#      lqpl1q         302636        63.499884
#        lseq         166125        34.856786
#      ltmibq         166380        34.910290
#         ltq         166384        34.911130
#       lul3q         302631        63.498834
#       mibnq         170505        35.775809
#        mibq         166701        34.977643
#       mibtq         170481        35.770773
#        miiq         163682        34.344189
#        msaq         189068        39.670746
#        ncoq         456480        95.779837
#       niitq         463705        97.295806
#        nimq         455728        95.622051
#         niq         156703        32.879837
#       nopiq         162408        34.076875
#       npatq         456336        95.749623
#         npq         200412        42.050974
#      nrtxtq         458963        96.300827
#      oepf12         179934        37.754226
#      oeps12         179933        37.754017
#      oepsxq         164409        34.496730
#      oiadpq         163397        34.284389
#      oibdpq         180466        37.865852
#      opepsq         164402        34.495261
#      optdrq         404873        84.951520
#    optfvgrq         410125        86.053509
#    optlifeq         402304        84.412486
#     optrfrq         401740        84.294146
#     optvolq         401346        84.211476
#         piq         158071        33.166874
#        pllq         453886        95.235557
#        pncq         475880        99.850396
#       pnc12         475909        99.856481
#     pnrshoq         169874        35.643411
#      ppegtq         283511        59.487026
#      ppentq         177040        37.147000
#       prcaq         475880        99.850396
#      prce12         475909        99.856481
#      prcraq         348968        73.221386
#      prshoq         168094        35.269926
#      pstknq         167473        35.139626
#       pstkq         167416        35.127667
#      pstkrq         166701        34.977643
#        rcaq         440252        92.374836
#        rcpq         417794        87.662639
#      rdipaq         373712        78.413237
#       rdipq         188619        39.576536
#       recdq         338557        71.036922
#      rectaq         187423        39.325588
#      rectoq         227526        47.740105
#       rectq         174297        36.571456
#      rectrq         219787        46.116288
#      recubq         383518        80.470758
#         req         182662        38.326623
#      reunaq         186945        39.225293
#       revtq         180658        37.906138
#        rllq         453926        95.243950
#        rraq         476400        99.959504
#       rra12         475810        99.835709
#   rstcheltq         428745        89.960406
#     rstcheq         402564        84.467040
#       saleq         157882        33.127218
#      seta12         456614        95.807954
#       setaq         459843        96.485471
#        spiq         162584        34.113804
#       sretq         466026        97.782804
#      stkcoq         217509        45.638312
#     stkcpaq         377053        79.114255
#        teqq         166490        34.933371
#       tfvaq         302676        63.508276
#      tfvceq         415438        87.168297
#       tfvlq         302686        63.510375
#        tieq         453132        95.077351
#        tiiq         453132        95.077351
#      tstknq         179441        37.650784
#       tstkq         169000        35.460026
#      txdbaq         201628        42.306119
#     txdbcaq         202963        42.586232
#     txdbclq         202563        42.502303
#       txdbq         188586        39.569612
#       txdiq         360218        75.581891
#     txditcq         209583        43.975258
#        txpq         209544        43.967075
#        txtq         157235        32.991462
#       uacoq         466710        97.926323
#        uaoq         466707        97.925693
#       uaptq         467612        98.115583
#        uddq         472441        99.128816
#       udmbq         472418        99.123990
#      udoltq         472220        99.082446
#        ugiq         466592        97.901564
#       uinvq         467161        98.020953
#       ulcoq         466710        97.926323
#     uniamiq         466576        97.898207
#    unopincq         466592        97.901564
#       utemq         475744        99.821861
#       wcapq         219521        46.060475
#        wdaq         463889        97.334413
#       xaccq         316549        66.419146
#       xidoq         156658        32.870395
#       xintq         212096        44.502542
#         xiq         156620        32.862421
#       xoprq         159678        33.504059
#        xrdq         342988        71.966647
#       xsgaq         213805        44.861129
#      acchgy         177233        37.187495
#     afudccy         472606        99.163437
#     afudciy         472574        99.156723
#        amcy         475355        99.740240
#     aolochy         180201        37.810249
#     apalchy         300009        62.948679
#        aqay         440139        92.351126
#        aqcy         185476        38.917063
#       capxy         177511        37.245826
#       cdvcy         466844        97.954439
#      chechy         175641        36.853458
#    cibegniy         166599        34.956241
#     cicurry         168960        35.451633
#    cidergly         168600        35.376097
#      cimiiy         166564        34.948898
#    ciothery         166876        35.014362
#      cipeny         167870        35.222926
#    cisecgly         168705        35.398128
#    citotaly         166423        34.919313
#         ciy         166553        34.946590
#       cogsy         158216        33.197298
#      cshpry         149515        31.371632
#       depcy         466944        97.975421
#   derhedgly         404643        84.903261
#      dilady         163463        34.298238
#      dilavy         163522        34.310617
#      dlcchy         302697        63.512683
#      dltisy         182824        38.360614
#       dltry         181340        38.049237
#         doy         156367        32.809336
#        dpcy         187435        39.328106
#         dpy         185022        38.821804
#       dteay         451869        94.812345
#        dvpy         156519        32.841229
#         dvy         178776        37.511252
#        fcay         354508        74.383803
#       fiaoy         176811        37.098950
#      fincfy         175609        36.846743
#       fopty         476553        99.991607
#      fsrcty         476553        99.991607
#      fusety         476553        99.991607
#     gdwlamy         476593       100.000000
#     gdwliay         470011        98.618947
#        glay         463310        97.212926
#      glceay         473660        99.384590
#       glivy         421410        88.421357
#        glpy         455164        95.503711
#    hedgegly         453966        95.252343
#      ibadjy         156365        32.808917
#      ibcomy         156406        32.817519
#        ibcy         180140        37.797450
#      ibmiiy         165857        34.800553
#         iby         156386        32.813323
#      intpny         277341        58.192420
#      invchy         208248        43.695144
#       itccy         473240        99.296465
#      ivacoy         176739        37.083843
#       ivchy         188991        39.654590
#      ivncfy         175609        36.846743
#     ivstchy         262140        55.002906
#        miiy         163423        34.289845
#       niity         463704        97.295596
#        nimy         471438        98.918364
#         niy         156431        32.822765
#       nopiy         162134        34.019383
#      nrtxty         458961        96.300407
#      oancfy         175427        36.808556
#      oepsxy         164235        34.460221
#      oiadpy         163067        34.215148
#      oibdpy         180189        37.807731
#      opepsy         164231        34.459381
#      optdry         398366        83.586205
#    optfvgry         403961        84.760162
#    optlifey         395328        82.948763
#     optrfry         394711        82.819303
#     optvoly         394266        82.725932
#       pdvcy         468027        98.202659
#         piy         157802        33.110432
#        plly         453884        95.235138
#    prstkccy         467145        98.017596
#     prstkcy         188452        39.541496
#    prstkpcy         466808        97.946885
#        rcay         440247        92.373786
#        rcpy         417751        87.653616
#      rdipay         373745        78.420161
#       rdipy         188389        39.528277
#      recchy         237040        49.736358
#       revty         180394        37.850745
#        rray         476399        99.959294
#        rrpy         476338        99.946495
#       saley         157612        33.070565
#     scstkcy         466846        97.954859
#       setay         459849        96.486730
#       setpy         452473        94.939078
#       sppey         219767        46.112091
#      sppivy         194694        40.851208
#     spstkcy         466777        97.940381
#       sstky         181478        38.078193
#      stkcoy         217314        45.597397
#     stkcpay         376926        79.087607
#        tdcy         467851        98.165731
#      tfvcey         415435        87.167667
#        tiey         453130        95.076931
#        tiiy         453130        95.076931
#      txachy         270441        56.744644
#       txdcy         206417        43.310959
#       txdiy         359939        75.523350
#       txpdy         297510        62.424333
#        txty         156967        32.935230
#    uaolochy         466885        97.963042
#       udvpy         466749        97.934506
#        ugiy         466590        97.901144
#     uniamiy         466574        97.897787
#    unopincy         466590        97.901144
#       uoisy         466885        97.963042
#      updvpy         466573        97.897577
#      uptacy         466803        97.945836
#       uspiy         466644        97.912475
#    usubdvpy         466927        97.971854
#       utmey         475742        99.821441
#     wcapchy         476593       100.000000
#      wcapcy         476593       100.000000
#        wday         463889        97.334413
#        wdpy         454475        95.359143
#      xidocy         180270        37.824727
#       xidoy         156386        32.813323
#       xinty         211840        44.448827
#         xiy         156350        32.805769
#       xopry         159398        33.445309
#        xrdy         342887        71.945455
#       xsgay         213545        44.806575
#       adjex         143887        30.190750
#      cshtrq         164295        34.472810
#      dvpspq         143994        30.213201
#      dvpsxq         143994        30.213201
#     mkvaltq         207774        43.595689
#       prccq         157260        32.996708
#       prchq         157262        32.997128
#       prclq         157258        32.996288
# ============================================================
#
# ============================================================
# EXACT DUPLICATES
# ============================================================
# Found 0 duplicate rows (0.00%)
# ------------------------------------------------------------
# No duplicates found
# ============================================================
#
# ============================================================
# NUMERIC COLUMNS ANALYSIS
# ============================================================
#                   min           max  na_count  na_percent
# fyearq   2.014000e+03  2.025000e+03       0.0    0.000000
# fqtr     1.000000e+00  4.000000e+00     125.0    0.026228
# exchg    0.000000e+00  2.100000e+01     127.0    0.026647
# fyr      1.000000e+00  1.200000e+01       0.0    0.000000
# ajexq    1.000000e-08  5.454545e+05       5.0    0.001049
# ...               ...           ...       ...         ...
# dvpsxq   0.000000e+00  2.569000e+03  143994.0   30.213201
# mkvaltq  0.000000e+00  3.766500e+06  207774.0   43.595689
# prccq    1.000000e-06  3.350000e+04  157260.0   32.996708
# prchq    1.000000e-06  4.475000e+04  157262.0   32.997128
# prclq    0.000000e+00  3.280000e+04  157258.0   32.996288
#
# [367 rows x 4 columns]
# ============================================================
#
# ============================================================
# CATEGORICAL/STRING COLUMNS ANALYSIS
# ============================================================
#
# [gvkey]
#   Missing: 0 (0.00%)
#   Unique values: 19,951
#   Top 10 values:
# gvkey
# 149264    56
# 065850    45
# 031372    44
# 007022    44
# 184053    44
# 266257    44
# 162146    44
# 108841    44
# 008092    44
# 002269    44
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [iid]
#   Missing: 30 (0.01%)
#   Unique values: 30
#   Top 10 values:
# iid
# 01     405798
# 01C     24749
# 90      20288
# 02      14157
# 03       4668
# 91       1920
# 04       1347
# 05        800
# 02C       475
# 92        413
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [datadate]
#   Missing: 0 (0.00%)
#   Unique values: 120
#   Top 10 values:
# datadate
# 2024-12-31    11819
# 2024-09-30    11793
# 2023-03-31    11705
# 2023-09-30    11688
# 2023-06-30    11678
# 2024-06-30    11656
# 2024-03-31    11645
# 2023-12-31    11622
# 2022-06-30    11556
# 2022-03-31    11550
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [conm]
#   Missing: 0 (0.00%)
#   Unique values: 19,950
#   Top 10 values:
# conm
# PIMCO CALIF MUN INCOME FD II    56
# CHARLES & COLVARD LTD           45
# DEEPMARKIT CORP                 44
# MIDCAP FINANCIAL INVSMT CORP    44
# ALGOMA STEEL GROUP INC          44
# COMPASS MINERALS INTL INC       44
# BRISTOW GROUP INC               44
# CANADIAN SPIRIT RESOURCES       44
# BLOCK H & R INC                 44
# MARCUS CORP                     44
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [tic]
#   Missing: 131 (0.03%)
#   Unique values: 19,931
#   Top 10 values:
# tic
# PCK      56
# CTHR     45
# GOK.     44
# MFIC     44
# MKTSF    44
# CMP      44
# CYRX     44
# ASTL     44
# VTOL     44
# MCS      44
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [cusip]
#   Missing: 119 (0.02%)
#   Unique values: 19,932
#   Top 10 values:
# cusip
# 72200M108    56
# 159765205    45
# 015658107    44
# 24380K402    44
# 093671105    44
# 229050307    44
# 11040G103    44
# 136637105    44
# 37611E102    44
# 20451N101    44
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [cik]
#   Missing: 150,799 (31.64%)
#   Unique values: 12,050
#   Top 10 values:
# cik
# 0001170300    56
# 0001015155    45
# 0000012659    44
# 0001525221    44
# 0001433551    44
# 0001860805    44
# 0001227654    44
# 0001124524    44
# 0000062234    44
# 0001698132    44
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [indfmt]
#   Missing: 0 (0.00%)
#   Unique values: 1
#   Top 10 values:
# indfmt
# INDL    476593
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [consol]
#   Missing: 0 (0.00%)
#   Unique values: 1
#   Top 10 values:
# consol
# C    476593
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [datafmt]
#   Missing: 0 (0.00%)
#   Unique values: 1
#   Top 10 values:
# datafmt
# STD    476593
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [popsrc]
#   Missing: 0 (0.00%)
#   Unique values: 1
#   Top 10 values:
# popsrc
# D    476593
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [acctchgq]
#   Missing: 464,400 (97.44%)
#   Unique values: 8
#   Top 10 values:
# acctchgq
# ASU16-02    5462
# ASU14-09    2538
# IFRS16      1460
# ASU16-13    1054
# IFRS15       552
# ASU17-07     389
# IFRS9        378
# ASU16-01     360
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [acctstdq]
#   Missing: 141,128 (29.61%)
#   Unique values: 4
#   Top 10 values:
# acctstdq
# DS    222296
# DI     83626
# DU     29537
# ND         6
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [apdedateq]
#   Missing: 164,784 (34.58%)
#   Unique values: 1,346
#   Top 10 values:
# apdedateq
# 2015-12-31    7392
# 2016-12-31    7347
# 2015-06-30    7205
# 2022-12-31    7199
# 2017-12-31    7151
# 2021-12-31    7145
# 2020-12-31    7084
# 2015-03-31    7069
# 2018-12-31    6952
# 2019-12-31    6948
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [bsprq]
#   Missing: 419,707 (88.06%)
#   Unique values: 1
#   Top 10 values:
# bsprq
# GB    56886
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [rdq]
#   Missing: 169,012 (35.46%)
#   Unique values: 3,125
#   Top 10 values:
# rdq
# 2022-11-14    803
# 2020-11-05    768
# 2024-11-07    737
# 2020-08-06    714
# 2020-05-07    706
# 2021-08-05    702
# 2022-08-04    691
# 2016-11-14    684
# 2024-08-08    679
# 2021-05-06    674
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [fdateq]
#   Missing: 140,657 (29.51%)
#   Unique values: 3,786
#   Top 10 values:
# fdateq
# 2020-08-20    423
# 2015-08-24    347
# 2015-06-11    325
# 2016-06-06    318
# 2015-09-01    312
# 2016-06-10    310
# 2024-11-11    309
# 2016-08-31    306
# 2015-12-01    305
# 2017-06-05    301
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [pdateq]
#   Missing: 279,300 (58.60%)
#   Unique values: 3,629
#   Top 10 values:
# pdateq
# 2017-08-15    420
# 2015-04-30    363
# 2020-08-22    349
# 2015-11-05    341
# 2017-05-04    339
# 2016-04-28    325
# 2015-05-07    319
# 2017-08-03    316
# 2015-08-06    312
# 2016-07-28    307
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [finalq]
#   Missing: 140,651 (29.51%)
#   Unique values: 1
#   Top 10 values:
# finalq
# Y    335942
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [compstq]
#   Missing: 454,394 (95.34%)
#   Unique values: 16
#   Top 10 values:
# compstq
# AC    9465
# AZ    8914
# DZ    1695
# AA     618
# AT     386
# DB     384
# CE     359
# AB      96
# CF      85
# AG      71
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [curncdq]
#   Missing: 163,112 (34.22%)
#   Unique values: 39
#   Top 10 values:
# curncdq
# USD    244635
# CAD     49002
# CNY      5025
# EUR      4546
# JPY      1565
# BRL      1330
# GBP      1214
# MXN       632
# AUD       574
# ARS       542
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [datacqtr]
#   Missing: 504 (0.11%)
#   Unique values: 41
#   Top 10 values:
# datacqtr
# 2024Q3    12670
# 2023Q1    12647
# 2023Q3    12607
# 2023Q2    12605
# 2024Q1    12542
# 2024Q2    12540
# 2023Q4    12535
# 2022Q1    12524
# 2022Q2    12523
# 2022Q3    12507
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [datafqtr]
#   Missing: 130 (0.03%)
#   Unique values: 44
#   Top 10 values:
# datafqtr
# 2023Q1    12691
# 2023Q2    12642
# 2023Q3    12633
# 2022Q1    12586
# 2024Q2    12574
# 2024Q1    12568
# 2022Q2    12550
# 2023Q4    12525
# 2022Q3    12506
# 2024Q3    12500
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [staltq]
#   Missing: 476,092 (99.89%)
#   Unique values: 1
#   Top 10 values:
# staltq
# TL    501
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [gdwlamq]
#   Missing: 476,593 (100.00%)
#   Unique values: 0
#   Top 10 values:
# Series([], Name: count, dtype: Int64)
# ------------------------------------------------------------
#
# [gdwlamy]
#   Missing: 476,593 (100.00%)
#   Unique values: 0
#   Top 10 values:
# Series([], Name: count, dtype: Int64)
# ------------------------------------------------------------
#
# [wcapchy]
#   Missing: 476,593 (100.00%)
#   Unique values: 0
#   Top 10 values:
# Series([], Name: count, dtype: Int64)
# ------------------------------------------------------------
#
# [wcapcy]
#   Missing: 476,593 (100.00%)
#   Unique values: 0
#   Top 10 values:
# Series([], Name: count, dtype: Int64)
# ------------------------------------------------------------
# ============================================================
# contains permno False
# contains iid True

# %%
# CCM Link
from bearplanes.utils import get_raw_data_dir
from bearplanes.data.wrds.compustat.fields import OUTPUT_DIR
from bearplanes.utils import get_processed_data_dir
from pathlib import Path
import pandas as pd

from bearplanes.utils.paths import *
from bearplanes.utils.adjustment import *
from bearplanes.utils.describe_dataframes import *
from bearplanes.data.wrds.crsp.crsp_compustat_link import *

# Load in raw taq data to refilter
ccm_link = get_raw_data_dir(source='wrds', dataset='crsp_compustat_link')
data_path = ccm_link / 'ccm_link.parquet'

df = pd.read_parquet(data_path)
df.cust.describe()
print(df)
# Out:
# Loading library list...
# Done
# Downloaded 39,232 linkages
# Columns: gvkey, permno, permco, linktype, linkprim, linkdt, linkenddt, iid
#
# ============================================================
# BASIC INFORMATION
# ============================================================
# Dimensions: 39,232 rows × 8 columns
# ------------------------------------------------------------
# Column Data Types:
# gvkey        string[python]
# permno              Float64
# permco              Float64
# linktype     string[python]
# linkprim     string[python]
# linkdt       string[python]
# linkenddt    string[python]
# iid          string[python]
# dtype: object
# ============================================================
#
# ============================================================
# MEMORY USAGE
# ============================================================
# Total memory: 12.81 MB
# ============================================================
#
# ============================================================
# MISSING VALUES ANALYSIS
# ============================================================
# column_name  missing_count  percent_missing
#       gvkey              0         0.000000
#      permno              0         0.000000
#      permco              0         0.000000
#    linktype              0         0.000000
#    linkprim              0         0.000000
#      linkdt              0         0.000000
#   linkenddt          10386        26.473287
#         iid              0         0.000000
# ============================================================
#
# ============================================================
# EXACT DUPLICATES
# ============================================================
# Found 0 duplicate rows (0.00%)
# ------------------------------------------------------------
# No duplicates found
# ============================================================
#
# ============================================================
# NUMERIC COLUMNS ANALYSIS
# ============================================================
#             min      max  na_count  na_percent
# permno  10000.0  93436.0       0.0         0.0
# permco      2.0  60123.0       0.0         0.0
# ============================================================
#
# ============================================================
# CATEGORICAL/STRING COLUMNS ANALYSIS
# ============================================================
#
# [gvkey]
#   Missing: 0 (0.00%)
#   Unique values: 34,377
#   Top 10 values:
# gvkey
# 032280    10
# 017010     8
# 003581     8
# 100384     8
# 007466     8
# 003226     8
# 002975     7
# 010121     7
# 002163     6
# 007066     6
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [linktype]
#   Missing: 0 (0.00%)
#   Unique values: 3
#   Top 10 values:
# linktype
# LC    17337
# LU    15950
# LS     5945
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [linkprim]
#   Missing: 0 (0.00%)
#   Unique values: 3
#   Top 10 values:
# linkprim
# P    30711
# C     8082
# J      439
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [linkdt]
#   Missing: 0 (0.00%)
#   Unique values: 11,000
#   Top 10 values:
# linkdt
# 1972-12-14    1333
# 1962-01-31     679
# 1979-01-31     337
# 1950-01-01     270
# 1962-07-02     233
# 1982-01-29     219
# 1974-01-01     215
# 1978-01-31     210
# 1966-01-31     196
# 1982-01-01     112
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [linkenddt]
#   Missing: 10,386 (26.47%)
#   Unique values: 7,091
#   Top 10 values:
# linkenddt
# 1962-01-30    550
# 1979-01-30    171
# 1978-01-30    158
# 1982-01-28    129
# 2022-12-30    104
# 2022-10-31     73
# 2023-06-30     71
# 2000-12-29     69
# 2000-03-31     69
# 2023-03-31     67
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [iid]
#   Missing: 0 (0.00%)
#   Unique values: 24
#   Top 10 values:
# iid
# 01     32757
# 00X     2295
# 02      2139
# 90      1271
# 03       393
# 04        94
# 99X       87
# 91        85
# 05        44
# 92        16
# Name: count, dtype: Int64
# ------------------------------------------------------------
# ============================================================
#         gvkey   permno   permco linktype linkprim      linkdt   linkenddt iid
# 0      001000  25881.0  23369.0       LU        P  1970-11-13  1978-06-30  01
# 1      001001  10015.0   6398.0       LU        P  1983-09-20  1986-07-31  01
# 2      001002  10023.0  22159.0       LC        C  1972-12-14  1973-06-05  01
# 3      001003  10031.0   6672.0       LU        C  1983-12-07  1989-08-16  01
# 4      001004  54594.0  20000.0       LU        P  1972-04-24        <NA>  01
# ...       ...      ...      ...      ...      ...         ...         ...  ..
# 39227  353444  23209.0  59330.0       LC        P  2022-07-22        <NA>  90
# 39228  354003  23698.0  37493.0       LS        P  2023-02-24        <NA>  01
# 39229  355398  25134.0  59886.0       LC        P  2024-05-17        <NA>  90
# 39230  356128  24704.0  59765.0       LC        C  2024-01-19        <NA>  90
# 39231  356289  25036.0  59860.0       LC        P  2024-04-08        <NA>  01
#
# [39232 rows x 8 columns]

# %%
# TAQ processed data
from bearplanes.utils import get_raw_data_dir
from bearplanes.data.wrds.compustat.fields import OUTPUT_DIR
from bearplanes.utils import get_processed_data_dir
from pathlib import Path
import pandas as pd

from bearplanes.utils.paths import *
from bearplanes.utils.adjustment import *
from bearplanes.utils.describe_dataframes import *
from bearplanes.data.wrds.crsp.crsp_compustat_link import *

# Load in taq data
taq_files = get_processed_data_dir(source='wrds', dataset='taq')
data_path = taq_files / '30_min_combined.parquet'

df = pd.read_parquet(data_path)

df.cust.describe()
print(df)
# Out:
# ============================================================
# BASIC INFORMATION
# ============================================================
# Dimensions: 8,292,549 rows × 15 columns
# ------------------------------------------------------------
# Column Data Types:
# time_m         string[python]
# ex             string[python]
# sym_root       string[python]
# sym_suffix     string[python]
# bid                   Float64
# bidsiz                  Int64
# ask                   Float64
# asksiz                  Int64
# qu_cond        string[python]
# qu_seqnum               Int64
# qu_source      string[python]
# trade_date     string[python]
# permno                  Int64
# bucket_time    string[python]
# midpoint              Float64
# dtype: object
# ============================================================
#
# ============================================================
# MEMORY USAGE
# ============================================================
# Total memory: 3961.69 MB
# ============================================================
#
# ============================================================
# MISSING VALUES ANALYSIS
# ============================================================
# column_name  missing_count  percent_missing
#      time_m              0         0.000000
#          ex              0         0.000000
#    sym_root              0         0.000000
#  sym_suffix        7458885        89.946831
#         bid              0         0.000000
#      bidsiz              0         0.000000
#         ask              0         0.000000
#      asksiz              0         0.000000
#     qu_cond              0         0.000000
#   qu_seqnum              0         0.000000
#   qu_source              0         0.000000
#  trade_date              0         0.000000
#      permno              0         0.000000
# bucket_time              0         0.000000
#    midpoint              0         0.000000
# ============================================================
#
# ============================================================
# EXACT DUPLICATES
# ============================================================
# Found 0 duplicate rows (0.00%)
# ------------------------------------------------------------
# No duplicates found
# ============================================================
#
# ============================================================
# NUMERIC COLUMNS ANALYSIS
# ============================================================
#                     min          max  na_count  na_percent
# bid        1.000000e-04     285720.0       0.0         0.0
# bidsiz     0.000000e+00      81547.0       0.0         0.0
# ask        3.000000e-04     400000.0       0.0         0.0
# asksiz     0.000000e+00      28085.0       0.0         0.0
# qu_seqnum  1.135019e+06  548176370.0       0.0         0.0
# permno     1.010400e+04      93436.0       0.0         0.0
# midpoint   2.500000e-04     285775.0       0.0         0.0
# ============================================================
#
# ============================================================
# CATEGORICAL/STRING COLUMNS ANALYSIS
# ============================================================
#
# [time_m]
#   Missing: 0 (0.00%)
#   Unique values: 7,624,309
#   Top 10 values:
# time_m
# 16:00:00           1006
# 15:59:59.999000     544
# 15:59:59.998000     307
# 15:59:59.995000     254
# 15:59:59.997000     226
# 15:59:59.996000     216
# 15:59:59.994000     211
# 15:59:59.905000     202
# 15:59:59.904000     200
# 15:59:59.991000     190
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [ex]
#   Missing: 0 (0.00%)
#   Unique values: 17
#   Top 10 values:
# ex
# Q    3293501
# N    1577819
# T     786320
# P     684340
# Z     470975
# K     438414
# M     185707
# U     175188
# V     157718
# X     143208
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [sym_root]
#   Missing: 0 (0.00%)
#   Unique values: 2,348
#   Top 10 values:
# sym_root
# AGNC    88816
# HBAN    65170
# FITB    63712
# C       52478
# WFC     43656
# GOOG    42144
# BAC     34726
# EBAY    33871
# JPM     31059
# NEE     28391
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [sym_suffix]
#   Missing: 7,458,885 (89.95%)
#   Unique values: 57
#   Top 10 values:
# sym_suffix
# W      163892
# P       93138
# O       51097
# L       49191
# U       45509
# N       38281
# PRA     32845
# PRC     26943
# M       24124
# PRB     21410
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [qu_cond]
#   Missing: 0 (0.00%)
#   Unique values: 9
#   Top 10 values:
# qu_cond
# R    8291612
# W        557
# N        253
# C         99
# M         11
# P          7
# G          7
# I          2
# O          1
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [qu_source]
#   Missing: 0 (0.00%)
#   Unique values: 2
#   Top 10 values:
# qu_source
# N    5667888
# C    2624661
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [trade_date]
#   Missing: 0 (0.00%)
#   Unique values: 2,215
#   Top 10 values:
# trade_date
# 2016-10-25    7441
# 2016-11-10    7419
# 2016-11-14    7409
# 2016-11-18    7392
# 2016-11-16    7385
# 2016-11-15    7382
# 2016-11-11    7381
# 2016-10-24    7374
# 2016-10-28    7373
# 2016-10-31    7368
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [bucket_time]
#   Missing: 0 (0.00%)
#   Unique values: 12
#   Top 10 values:
# bucket_time
# 16:00:00    707088
# 10:30:00    700065
# 11:00:00    695733
# 11:30:00    692736
# 12:00:00    690883
# 15:30:00    689394
# 12:30:00    688133
# 13:00:00    687521
# 13:30:00    685963
# 15:00:00    685108
# Name: count, dtype: Int64
# ------------------------------------------------------------
# ============================================================
#                   time_m ex sym_root sym_suffix    bid  bidsiz    ask  asksiz  \
# 0        10:29:58.160000  T       AA       <NA>  15.86       8  15.87      20
# 1        10:59:53.222000  T       AA       <NA>   15.8      29  15.81      39
# 2        11:29:59.178000  T       AA       <NA>  15.73      22  15.74     111
# 3        11:59:24.656000  T       AA       <NA>  15.79      19   15.8      37
# 4        12:29:31.719000  Z       AA       <NA>  15.79      25   15.8      20
# ...                  ... ..      ...        ...    ...     ...    ...     ...
# 8292544  13:59:56.921967  Q       ZI       <NA>  10.44      22  10.45      90
# 8292545  14:29:54.449264  Q       ZI       <NA>  10.43      17  10.44      35
# 8292546  14:59:47.689206  L       ZI       <NA>  10.42      30  10.43      30
# 8292547  15:29:55.454772  L       ZI       <NA>  10.45      37  10.46      28
# 8292548  15:59:59.996951  Q       ZI       <NA>  10.52      34  10.53     434
#
#         qu_cond  qu_seqnum qu_source  trade_date  permno bucket_time  midpoint
# 0             R    3740547         C  2015-01-02   24643    10:30:00    15.865
# 1             R    5759479         C  2015-01-02   24643    11:00:00    15.805
# 2             R    7636571         C  2015-01-02   24643    11:30:00    15.735
# 3             R    9119912         C  2015-01-02   24643    12:00:00    15.795
# 4             R   10435791         C  2015-01-02   24643    12:30:00    15.795
# ...         ...        ...       ...         ...     ...         ...       ...
# 8292544       R   91624199         N  2024-12-31   19405    14:00:00    10.445
# 8292545       R   98969115         N  2024-12-31   19405    14:30:00    10.435
# 8292546       R  105857194         N  2024-12-31   19405    15:00:00    10.425
# 8292547       R  113319502         N  2024-12-31   19405    15:30:00    10.455
# 8292548       R  125536400         N  2024-12-31   19405    16:00:00    10.525
#
# [8292549 rows x 15 columns]

# %%
# CRSP
from pathlib import Path
import pandas as pd

from bearplanes.utils.paths import *
from bearplanes.utils.adjustment import *
from bearplanes.utils.describe_dataframes import *

# Load in crsp data for share price adjustment
crsp_data = get_processed_data_dir(source='wrds', dataset='crsp')
crsp_data_path = crsp_data / 'crsp_dsf_combined.parquet'

crsp_df = pd.read_parquet(crsp_data_path)
print(crsp_df)
crsp_df.cust.describe()
# Out:
#           permno  permco  hdrcusip     cusip ticker   shrout  siccd  \
# 0          10001    7953  36720410  29269V10   EGAS     4361   4925
# 1          10002    7954  05978R10  05978R10   BTFG    17634   6020
# 2          10025    7975  00103110  00103110   AEPI     6852   3081
# 3          10026    7976  46603210  46603210   JJSF    18374   2052
# 4          10028    7978  29402E10  23323G10   DGSE     9834   5094
# ...          ...     ...       ...       ...    ...      ...    ...
# 29132302   93426   53443  92835K10  92835K10    VPG    12216   3676
# 29132303   93427   53445  G3323L10  G3323L10     FN    36268   3826
# 29132304   93429   53447  12503M10  12503M10   CBOE   104686   6211
# 29132305   93434   53427  78513530  78513530   SANW     2139    139
# 29132306   93436   53453  88160R10  88160R10   TSLA  3216517   3711
#
#             dlycaldt sharetype securitytype  ... tradingstatusflg  \
# 0         2010-01-04        NS         EQTY  ...                A
# 1         2010-01-04        NS         EQTY  ...                A
# 2         2010-01-04        NS         EQTY  ...                A
# 3         2010-01-04        NS         EQTY  ...                A
# 4         2010-01-04        NS         EQTY  ...                A
# ...              ...       ...          ...  ...              ...
# 29132302  2024-12-31        NS         EQTY  ...                A
# 29132303  2024-12-31        NS         EQTY  ...                A
# 29132304  2024-12-31        NS         EQTY  ...                A
# 29132305  2024-12-31        NS         EQTY  ...                A
# 29132306  2024-12-31        NS         EQTY  ...                A
#
#                 dlycap dlycapflg dlydistretflg      dlyvol  dlyopen dlyhigh  \
# 0         4.470025e+04        BP            NO     18500.0    10.58   10.58
# 1         5.466540e+04        BP            NO     27845.0     2.85    3.28
# 2         2.710651e+05        BP            NO     33721.0    38.57   39.76
# 3         7.386348e+05        BP            NO     47859.0    40.55   40.55
# 4         1.376858e+04        BP            NO      3900.0     1.40    1.42
# ...                ...       ...           ...         ...      ...     ...
# 29132302  2.867095e+05        BP            NO     62710.0    23.54   24.22
# 29132303  7.974608e+06        BP            NO    416107.0   215.23  220.78
# 29132304  2.045564e+07        BP            NO    471701.0   196.40  196.62
# 29132305  1.709061e+04        BP            NO     12585.0     9.00    9.00
# 29132306  1.298958e+09        BP            NO  76455216.0   423.79  427.93
#
#             dlylow  dlyclose  dlycumfacshr
# 0          10.1000   10.2500           1.0
# 1           2.7500    3.1000           1.0
# 2          38.0000   39.5600           1.0
# 3          39.7500   40.2000           1.0
# 4           1.3300    1.4001           1.0
# ...            ...       ...           ...
# 29132302   23.4025   23.4700           1.0
# 29132303  213.7200  219.8800           1.0
# 29132304  194.5250  195.4000           1.0
# 29132305    7.6100    7.9900           1.0
# 29132306  402.5400  403.8400           1.0
#
# [29132307 rows x 24 columns]
#
# ============================================================
# BASIC INFORMATION
# ============================================================
# Dimensions: 29,132,307 rows × 24 columns
# ------------------------------------------------------------
# Column Data Types:
# permno                       int32
# permco                       int32
# hdrcusip            string[python]
# cusip               string[python]
# ticker              string[python]
# shrout                       Int32
# siccd                        int16
# dlycaldt            string[python]
# sharetype           string[python]
# securitytype              category
# securitysubtype           category
# usincflg                  category
# primaryexch         string[python]
# conditionaltype     string[python]
# tradingstatusflg    string[python]
# dlycap                     float64
# dlycapflg                 category
# dlydistretflg       string[python]
# dlyvol                     float32
# dlyopen                    float64
# dlyhigh                    float64
# dlylow                     float64
# dlyclose                   float64
# dlycumfacshr               float64
# dtype: object
# ============================================================
#
# ============================================================
# MEMORY USAGE
# ============================================================
# Total memory: 15268.52 MB
# ============================================================
#
# ============================================================
# MISSING VALUES ANALYSIS
# ============================================================
#      column_name  missing_count  percent_missing
#           permno              0         0.000000
#           permco              0         0.000000
#         hdrcusip              0         0.000000
#            cusip           7553         0.025927
#           ticker         219728         0.754242
#           shrout           7553         0.025927
#            siccd              0         0.000000
#         dlycaldt              0         0.000000
#        sharetype              8         0.000027
#     securitytype              8         0.000027
#  securitysubtype              8         0.000027
#         usincflg              8         0.000027
#      primaryexch              8         0.000027
#  conditionaltype              8         0.000027
# tradingstatusflg              8         0.000027
#           dlycap         226531         0.777594
#        dlycapflg              0         0.000000
#    dlydistretflg              0         0.000000
#           dlyvol         226545         0.777642
#          dlyopen        1017593         3.493005
#          dlyhigh        1017468         3.492576
#           dlylow        1017468         3.492576
#         dlyclose        1017468         3.492576
#     dlycumfacshr           7553         0.025927
# ============================================================
#
# ============================================================
# EXACT DUPLICATES
# ============================================================
# Found 0 duplicate rows (0.00%)
# ------------------------------------------------------------
# No duplicates found
# ============================================================
#
# ============================================================
# NUMERIC COLUMNS ANALYSIS
# ============================================================
#                      min           max   na_count  na_percent
# permno        10001.0000  9.343600e+04        0.0    0.000000
# permco            5.0000  6.012300e+04        0.0    0.000000
# shrout            2.0000  2.920640e+07     7553.0    0.025927
# siccd             0.0000  9.999000e+03        0.0    0.000000
# dlycap            8.0700  3.915300e+09   226531.0    0.777594
# dlyvol            0.0000  3.363241e+09   226545.0    0.777642
# dlyopen           0.0001  7.300908e+05  1017593.0    3.493005
# dlyhigh           0.0014  7.419714e+05  1017468.0    3.492576
# dlylow            0.0001  7.230500e+05  1017468.0    3.492576
# dlyclose          0.0006  7.240400e+05  1017468.0    3.492576
# dlycumfacshr      0.0000  1.920000e+02     7553.0    0.025927
# ============================================================
#
# ============================================================
# CATEGORICAL/STRING COLUMNS ANALYSIS
# ============================================================
#
# [hdrcusip]
#   Missing: 0 (0.00%)
#   Unique values: 17,303
#   Top 10 values:
# hdrcusip
# 77467X10    3774
# 72913210    3774
# 92204A60    3774
# 92204A88    3774
# 92290855    3774
# 85916J40    3774
# 64420610    3774
# 96041310    3774
# G2125H10    3774
# 20260810    3774
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [cusip]
#   Missing: 7,553 (0.03%)
#   Unique values: 22,648
#   Top 10 values:
# cusip
# 03050610    3774
# 91307C10    3774
# 82620P10    3774
# 52610710    3774
# 28225C80    3774
# M8187310    3774
# 48203R10    3774
# M1534210    3774
# 89011010    3774
# 05766520    3774
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [ticker]
#   Missing: 219,728 (0.75%)
#   Unique values: 18,145
#   Top 10 values:
# ticker
# GTN    7548
# HEI    7548
# TAP    7548
# LEN    7548
# MKC    7548
# BIO    7548
# BF     7548
# CRD    7548
# BRK    7548
# HVT    7548
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [dlycaldt]
#   Missing: 0 (0.00%)
#   Unique values: 3,774
#   Top 10 values:
# dlycaldt
# 2024-12-23    9762
# 2024-12-20    9760
# 2024-12-30    9755
# 2024-12-24    9753
# 2024-12-27    9752
# 2024-12-31    9751
# 2024-12-26    9748
# 2024-12-19    9748
# 2024-12-18    9746
# 2024-12-16    9744
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [sharetype]
#   Missing: 8 (0.00%)
#   Unique values: 6
#   Top 10 values:
# sharetype
# NS     25923233
# AD      1378645
# SB      1269139
# UG       549641
# N/A        7545
# CE         4096
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [securitytype]
#   Missing: 8 (0.00%)
#   Unique values: 3
#   Top 10 values:
# securitytype
# EQTY    19585316
# FUND     9539438
# N/A         7545
# Name: count, dtype: int64
# ------------------------------------------------------------
#
# [securitysubtype]
#   Missing: 8 (0.00%)
#   Unique values: 5
#   Top 10 values:
# securitysubtype
# COM    19585316
# ETF     7276149
# CEF     2158750
# ETV      104539
# UNK        7545
# Name: count, dtype: int64
# ------------------------------------------------------------
#
# [usincflg]
#   Missing: 8 (0.00%)
#   Unique values: 2
#   Top 10 values:
# usincflg
# Y    25325487
# N     3806812
# Name: count, dtype: int64
# ------------------------------------------------------------
#
# [primaryexch]
#   Missing: 8 (0.00%)
#   Unique values: 7
#   Top 10 values:
# primaryexch
# Q    11948203
# N     9419875
# R     5333676
# A     1275075
# B      935499
# X      219720
# I         251
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [conditionaltype]
#   Missing: 8 (0.00%)
#   Unique values: 4
#   Top 10 values:
# conditionaltype
# RW     28912503
# NT       212175
# N/A        7545
# NW           76
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [tradingstatusflg]
#   Missing: 8 (0.00%)
#   Unique values: 5
#   Top 10 values:
# tradingstatusflg
# A    28908020
# X      212175
# D        7545
# S        4222
# H         337
# Name: count, dtype: Int64
# ------------------------------------------------------------
#
# [dlycapflg]
#   Missing: 0 (0.00%)
#   Unique values: 5
#   Top 10 values:
# dlycapflg
# BP    27532156
# AD     1378645
# NT      207682
# DE        7553
# MP        6271
# Name: count, dtype: int64
# ------------------------------------------------------------
#
# [dlydistretflg]
#   Missing: 0 (0.00%)
#   Unique values: 13
#   Top 10 values:
# dlydistretflg
# NO    28792476
# C1      321081
# D1        5168
# S1        4262
# M2        2872
# C2        2012
# O1        1607
# N1        1200
# P1         599
# D2         592
# Name: count, dtype: Int64
# ------------------------------------------------------------
# ============================================================

# %%
# Merge ccm into TAQ
from pathlib import Path
import pandas as pd

from bearplanes.utils.paths import *
from bearplanes.utils.adjustment import *
from bearplanes.utils.describe_dataframes import *

# Load in TAQ data
taq_data = get_processed_data_dir(source='wrds', dataset='taq')
taq_data_path = taq_data / '30_min_combined.parquet'
taq_df = pd.read_parquet(taq_data_path)

# Load in ccm link data
ccm_data = get_raw_data_dir(source='wrds', dataset='crsp_compustat_link')
ccm_data_path = ccm_data / 'ccm_link.parquet'
ccm_df = pd.read_parquet(ccm_data_path)

# Load in crsp data for share price adjustment
crsp_data = get_processed_data_dir(source='wrds', dataset='crsp')
crsp_data_path = crsp_data / 'crsp_dsf_combined.parquet'
crsp_df = pd.read_parquet(crsp_data_path)
# Confirm dlycaldt is a datetime
crsp_df['dlycaldt'] = pd.to_datetime(crsp_df['dlycaldt'])

## CCM ##
# pre-filter ccm
ccm_df = ccm_df[
    (ccm_df['linktype'].isin(['LC', 'LU'])) &
    (ccm_df['linkprim'] == 'P')
]

# Convert ccm dates 
ccm_df['linkdt'] = pd.to_datetime(ccm_df['linkdt'])
ccm_df['linkenddt'] = pd.to_datetime(ccm_df['linkenddt']).fillna(pd.to_datetime('2099-12-31'))

## TAQ ##
# Convert TAQ dates
taq_df['trade_date'] = pd.to_datetime(taq_df['trade_date'])

## Merge ## 
taq_merged = pd.merge(taq_df, ccm_df, how='left', on='permno')

# Check coverage
total_rows = len(taq_merged)
rows_with_gvkey = taq_merged['gvkey'].notna().sum()
rows_with_iid = taq_merged['iid'].notna().sum()

# Filter to keep ONLY rows with valid CCM links where the TAQ trade date is within the linkdt and linkenddt and the 
# gvkey and iid is there (not na), this turns out to be 87% of the TAQ data we have selected, ~7m rows
taq_merged = taq_merged[
    (taq_merged['trade_date'] >= taq_merged['linkdt']) &
    (taq_merged['trade_date'] <= taq_merged['linkenddt']) &
    (taq_merged['gvkey'].notna()) &
    (taq_merged['iid'].notna())
].copy()

# Just rename the CRSP column to match TAQ
crsp_df = crsp_df.rename(columns={'dlycaldt': 'trade_date'})

# Then merge (no need to rename taq_merged at all)
taq_crsp_merge = pd.merge(taq_merged, crsp_df, how='left', on=['permno', 'trade_date'])

print(taq_crsp_merge)
print(taq_crsp_merge.columns())

# Adjust volume, shares, and price amounts with adjustment function
# crsp_df = adjust_with_cumfacshr(crsp_df)
# crsp_selected_columns = ['dlycaldt', 'permno', 'dlycumfacshr', 'shrout', 'dlycap']
# crsp_adjustment = crsp_df[crsp_selected_columns]

# # Create 30 min returns
# taq_crsp_merge = taq_crsp_merge.sort_values(by=["permno", "trade_date"])
# sort intra day timestamps
# taq_crsp_merge['30_min_ret'] = taq_crsp_merge.groupby('permno')['midpoint'].pct_change()
# Out:
#                   time_m ex sym_root sym_suffix    bid  bidsiz    ask  asksiz  \
# 0        10:29:58.160000  T       AA       <NA>  15.86       8  15.87      20
# 1        10:59:53.222000  T       AA       <NA>   15.8      29  15.81      39
# 2        11:29:59.178000  T       AA       <NA>  15.73      22  15.74     111
# 3        11:59:24.656000  T       AA       <NA>  15.79      19   15.8      37
# 4        12:29:31.719000  Z       AA       <NA>  15.79      25   15.8      20
# ...                  ... ..      ...        ...    ...     ...    ...     ...
# 7957346  13:59:56.921967  Q       ZI       <NA>  10.44      22  10.45      90
# 7957347  14:29:54.449264  Q       ZI       <NA>  10.43      17  10.44      35
# 7957348  14:59:47.689206  L       ZI       <NA>  10.42      30  10.43      30
# 7957349  15:29:55.454772  L       ZI       <NA>  10.45      37  10.46      28
# 7957350  15:59:59.996951  Q       ZI       <NA>  10.52      34  10.53     434
#
#         qu_cond  qu_seqnum  ... tradingstatusflg       dlycap  dlycapflg  \
# 0             R    3740547  ...                A  18719709.24         BP
# 1             R    5759479  ...                A  18719709.24         BP
# 2             R    7636571  ...                A  18719709.24         BP
# 3             R    9119912  ...                A  18719709.24         BP
# 4             R   10435791  ...                A  18719709.24         BP
# ...         ...        ...  ...              ...          ...        ...
# 7957346       R   91624199  ...                A   3594714.28         BP
# 7957347       R   98969115  ...                A   3594714.28         BP
# 7957348       R  105857194  ...                A   3594714.28         BP
# 7957349       R  113319502  ...                A   3594714.28         BP
# 7957350       R  125536400  ...                A   3594714.28         BP
#
#         dlydistretflg      dlyvol dlyopen  dlyhigh  dlylow dlyclose  \
# 0                  NO  10430015.0   15.87   15.980  15.670    15.88
# 1                  NO  10430015.0   15.87   15.980  15.670    15.88
# 2                  NO  10430015.0   15.87   15.980  15.670    15.88
# 3                  NO  10430015.0   15.87   15.980  15.670    15.88
# 4                  NO  10430015.0   15.87   15.980  15.670    15.88
# ...               ...         ...     ...      ...     ...      ...
# 7957346            NO   9789258.0   10.49   10.705  10.385    10.51
# 7957347            NO   9789258.0   10.49   10.705  10.385    10.51
# 7957348            NO   9789258.0   10.49   10.705  10.385    10.51
# 7957349            NO   9789258.0   10.49   10.705  10.385    10.51
# 7957350            NO   9789258.0   10.49   10.705  10.385    10.51
#
#         dlycumfacshr
# 0           0.444444
# 1           0.444444
# 2           0.444444
# 3           0.444444
# 4           0.444444
# ...              ...
# 7957346     1.000000
# 7957347     1.000000
# 7957348     1.000000
# 7957349     1.000000
# 7957350     1.000000
#
# [7957351 rows x 44 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 65
#      62 taq_crsp_merge = pd.merge(taq_merged, crsp_df, how='left', on=['permno', 'trade_date'])
#      64 print(taq_crsp_merge)
# ---> 65 print(taq_crsp_merge.columns())
#      67 # Adjust volume, shares, and price amounts with adjustment function
#      68 # crsp_df = adjust_with_cumfacshr(crsp_df)
#      69 # crsp_selected_columns = ['dlycaldt', 'permno', 'dlycumfacshr', 'shrout', 'dlycap']
#    (...)     74 # sort intra day timestamps
#      75 # taq_crsp_merge['30_min_ret'] = taq_crsp_merge.groupby('permno')['midpoint'].pct_change()
#
# TypeError: 'Index' object is not callable

# %%
# Merge merge the merged TAQ data into compustat
from pathlib import Path
import pandas as pd

from bearplanes.utils.paths import *
from bearplanes.utils.adjustment import *
from bearplanes.utils.describe_dataframes import *
from bearplanes.data.wrds.crsp.crsp_compustat_link import *

# Load in compustat data 
compustat_file = get_raw_data_dir(source='wrds', dataset='compustat_fundamentals_q')
data_path = compustat_file / 'fundq_combined.parquet'
comp_df = pd.read_parquet(data_path)

# Load in the merged TAQ data with ccm link info

# %%
# Factors

# Pull in

# 1) Accruals 
# Calc: The annual change in noncash working capital minus depreciation and amortization expense, divided by 
# average total assets for the previous two fiscal years 
# noncash working capital = actq - chq - lctq
# D&A = dpy
# average total assets = atq.rolling(2).mean()

# 2) Asset Growth 
# Calc: The growth rate of total assets in the previous fiscal year
# = atq

# 3) Composite Equity Issues
# Calc: The 12-month growth in equity market capitalization minus the 12 month cumulative stock return
# 

# 4) Failure Probability
# Calc: Strictly following Campbell, Hilscher, and Szilagyi (2008)
# Cant access

# 5) Gross Profitability
# Calc: (Total Revenue - COGSs) / Total Assets

# 6) Investment to assets 
# Calc: The annual change in inventories scaled by lagged book value of assets

# 7) Momentum 
# Calc: Cumulative return over the past 22 to 252 days 

# 8) Net Operating Assets
# Calc: Operating Assets minus operating liabilities, divided by lagged? 

# 9) Net stock issues
# Calc: The annual log change in split adjusted shares outstanding

# 10) O Score
# Calc: Strictly following Ohlson 1980

# 11) Return on Assets
# Calc: The ratio of quarterly earnings to last quarters earnings

# 12) Beta
# Calc: 

# 13) Book to market
# Calc: The ratio of the book value of common equity to the market value of equity (ceqq / market cap)

# 14) Reversal 
# Calc: Cumulative return over the past 21 days

# 15) Size
# Calc: ln of market cap
